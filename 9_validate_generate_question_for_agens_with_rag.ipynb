# %%
import pickle

# Uloz answers do souboru pro zálohu
with open("answers_backup.pkl", "rb") as f:
    answers = pickle.load(f)

# %%
answers
# Out:
# [['E-BOOST_combined_text.txt',
#   'EDF-2025-LS-DA-SME-NT_combined_text.txt',
#   'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
#   'FABRIX_combined_text.txt',
#   'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
#   'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
#   'Ukraine-Ready4EU_combined_text.txt',
#   'UP-RISE_combined_text.txt'],
#  ['CERV-2025-CHILD_combined_text.txt',
#   'CERV-2025-CITIZENS-CIV_combined_text.txt',
#   'CREA-CROSS-2025-INNOVLAB_combined_text.txt',
#   'CREA-MEDIA-2025-CINNET_combined_text.txt',
#   'CREA-MEDIA-2025-FILMDIST_combined_text.txt',
#   'CREA-MEDIA-2025-FILMOVE_combined_text.txt',
#   'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
#   'EDF-2025-LS-DA-SME-NT_combined_text.txt',
#   'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
#   'ERA4Health_combined_text.txt',
#   'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt',
#   'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt',
#   'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt',
#   'ESC-HUMAID-2025-VOLUN_combined_text.txt',
#   'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
#   'ESF-2025-EURES-CBC_combined_text.txt',
#   'EUBA-EFSA-2025-PREV-02_combined_text.txt',
#   'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
#   'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
#   'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
#   'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
#   'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
#   'JUST-2025-JCOO_combined_text.txt',
#   'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt',
#   'PPPA-2025-COUNSEL_combined_text.txt',
#   'RFCS-2025-CSP_combined_text.txt',
#   'RFCS-2025-JT_combined_text.txt',
#   'SOCPL-2025-INFO-WK_combined_text.txt',
#   'UCPM-2025-KAPP-EX_combined_text.txt',
#   'UCPM-2025-TRACK1_combined_text.txt'],
#  ['CREA-CROSS-2025-INNOVLAB_combined_text.txt',
#   'CREA-MEDIA-2025-CINNET_combined_text.txt',
#   'CREA-MEDIA-2025-FILMDIST_combined_text.txt',
#   'CREA-MEDIA-2025-FILMOVE_combined_text.txt',
#   'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
#   'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
#   'EDF-2025-LS-DA-SME-NT_combined_text.txt',
#   'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
#   'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'ESC-HUMAID-2025-VOLUN_combined_text.txt',
#   'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
#   'ESF-2025-EURES-CBC_combined_text.txt',
#   'EUBA-EFSA-2025-PREV-02_combined_text.txt',
#   'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
#   'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
#   'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
#   'RFCS-2025-CSP_combined_text.txt',
#   'UCPM-2025-KAPP-EX_combined_text.txt'],
#  ['ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
#   'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
#   'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt'],
#  ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
#   'EDF-2025-LS-DA-SME-NT_combined_text.txt',
#   'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
#   'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt',
#   'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'ESC-HUMAID-2025-VOLUN_combined_text.txt',
#   'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
#   'ESF-2025-EURES-CBC_combined_text.txt',
#   'EUBA-EFSA-2025-PREV-02_combined_text.txt',
#   'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
#   'PPPA-2025-COUNSEL_combined_text.txt',
#   'RFCS-2025-CSP_combined_text.txt',
#   'UCPM-2025-KAPP-EX_combined_text.txt'],
#  ['CERV-2025-CHILD_combined_text.txt',
#   'CREA-CROSS-2025-INNOVLAB_combined_text.txt',
#   'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
#   'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
#   'EDF-2025-LS-DA-SME-NT_combined_text.txt',
#   'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
#   'ERA4Health_combined_text.txt',
#   'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'ESC-HUMAID-2025-VOLUN_combined_text.txt',
#   'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
#   'ESF-2025-EURES-CBC_combined_text.txt',
#   'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
#   'EUBA-EFSA-2025-PREV-02_combined_text.txt',
#   'FRONTIERS_combined_text.txt',
#   'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
#   'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
#   'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
#   'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
#   'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
#   'NGI0_Commons_Fund_combined_text.txt',
#   'PPPA-2025-COUNSEL_combined_text.txt',
#   'RFCS-2025-CSP_combined_text.txt',
#   'RFCS-2025-JT_combined_text.txt',
#   'UCPM-2025-KAPP-EX_combined_text.txt',
#   'UP-RISE_combined_text.txt'],
#  ['COPILOT_combined_text.txt',
#   'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
#   'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
#   'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
#   'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
#   'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt'],
#  ['CERV-2025-CHILD_combined_text.txt',
#   'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
#   'EDF-2025-LS-DA-SME-NT_combined_text.txt',
#   'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
#   'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt',
#   'ESC-HUMAID-2025-VOLUN_combined_text.txt',
#   'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
#   'ESF-2025-EURES-CBC_combined_text.txt',
#   'EUBA-EFSA-2025-PREV-02_combined_text.txt',
#   'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
#   'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
#   'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
#   'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
#   'PPPA-2025-COUNSEL_combined_text.txt',
#   'RFCS-2025-CSP_combined_text.txt',
#   'UCPM-2025-KAPP-EX_combined_text.txt',
#   'UCPM-2025-TRACK1_combined_text.txt'],
#  ['CERV-2025-CHILD_combined_text.txt',
#   'COPILOT_combined_text.txt',
#   'CREA-CROSS-2025-INNOVLAB_combined_text.txt',
#   'CREA-MEDIA-2025-CINNET_combined_text.txt',
#   'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
#   'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
#   'EDF-2025-LS-DA-SME-NT_combined_text.txt',
#   'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
#   'ERA4Health_combined_text.txt',
#   'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'ESC-HUMAID-2025-VOLUN_combined_text.txt',
#   'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
#   'ESF-2025-EURES-CBC_combined_text.txt',
#   'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
#   'EUBA-EFSA-2025-PREV-02_combined_text.txt',
#   'FRONTIERS_combined_text.txt',
#   'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
#   'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
#   'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
#   'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
#   'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
#   'NGI0_Commons_Fund_combined_text.txt',
#   'PPPA-2025-COUNSEL_combined_text.txt',
#   'PPPA-2025-DEPLAN_combined_text.txt',
#   'RFCS-2025-CSP_combined_text.txt',
#   'RFCS-2025-JT_combined_text.txt',
#   'SOCPL-2025-INFO-WK_combined_text.txt',
#   'UCPM-2025-KAPP-EX_combined_text.txt',
#   'UP-RISE_combined_text.txt'],
#  ['CERV-2025-CHILD_combined_text.txt',
#   'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
#   'EDF-2025-LS-DA-SME-NT_combined_text.txt',
#   'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
#   'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'ESC-HUMAID-2025-VOLUN_combined_text.txt',
#   'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
#   'ESF-2025-EURES-CBC_combined_text.txt',
#   'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
#   'EUBA-EFSA-2025-PREV-02_combined_text.txt',
#   'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
#   'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
#   'PPPA-2025-COUNSEL_combined_text.txt',
#   'RFCS-2025-CSP_combined_text.txt',
#   'UCPM-2025-KAPP-EX_combined_text.txt'],
#  ['CERV-2025-CHILD_combined_text.txt',
#   'CERV-2025-CITIZENS-CIV_combined_text.txt',
#   'CREA-CROSS-2025-INNOVLAB_combined_text.txt',
#   'CREA-MEDIA-2025-CINNET_combined_text.txt',
#   'CREA-MEDIA-2025-FILMDIST_combined_text.txt',
#   'CREA-MEDIA-2025-FILMOVE_combined_text.txt',
#   'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
#   'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
#   'E-BOOST_combined_text.txt',
#   'EDF-2025-LS-DA-SME-NT_combined_text.txt',
#   'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
#   'ERA4Health_combined_text.txt',
#   'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt',
#   'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt',
#   'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt',
#   'ESC-HUMAID-2025-VOLUN_combined_text.txt',
#   'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
#   'ESF-2025-EURES-CBC_combined_text.txt',
#   'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
#   'EUBA-EFSA-2025-PREV-02_combined_text.txt',
#   'FRONTIERS_combined_text.txt',
#   'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
#   'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
#   'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
#   'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
#   'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
#   'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt',
#   'JUST-2025-JCOO_combined_text.txt',
#   'OSCARS_combined_text.txt',
#   'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt',
#   'PPPA-2025-COUNSEL_combined_text.txt',
#   'PPPA-2025-DEPLAN_combined_text.txt',
#   'RFCS-2025-CSP_combined_text.txt',
#   'RFCS-2025-JT_combined_text.txt',
#   'SOCPL-2025-INFO-WK_combined_text.txt',
#   'UCPM-2025-KAPP-EX_combined_text.txt',
#   'UCPM-2025-TRACK1_combined_text.txt',
#   'Ukraine-Ready4EU_combined_text.txt',
#   'UP-RISE_combined_text.txt'],
#  ['CERV-2025-CHILD_combined_text.txt',
#   'COPILOT_combined_text.txt',
#   'CREA-CROSS-2025-INNOVLAB_combined_text.txt',
#   'CREA-MEDIA-2025-CINNET_combined_text.txt',
#   'CREA-MEDIA-2025-FILMOVE_combined_text.txt',
#   'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
#   'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
#   'E-BOOST_combined_text.txt',
#   'EDF-2025-LS-DA-SME-NT_combined_text.txt',
#   'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
#   'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
#   'ERA4Health_combined_text.txt',
#   'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt',
#   'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
#   'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt',
#   'ESC-HUMAID-2025-VOLUN_combined_text.txt',
#   'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
#   'ESF-2025-EURES-CBC_combined_text.txt',
#   'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
#   'EUBA-EFSA-2025-PREV-02_combined_text.txt',
#   'FABRIX_combined_text.txt',
#   'FRONTIERS_combined_text.txt',
#   'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
#   'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
#   'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
#   'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
#   'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
#   'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
#   'PPPA-2025-COUNSEL_combined_text.txt',
#   'RFCS-2025-CSP_combined_text.txt',
#   'RFCS-2025-JT_combined_text.txt',
#   'SOCPL-2025-INFO-WK_combined_text.txt',
#   'UCPM-2025-KAPP-EX_combined_text.txt',
#   'UCPM-2025-TRACK1_combined_text.txt',
#   'Ukraine-Ready4EU_combined_text.txt',
#   'UP-RISE_combined_text.txt']]

# %%
true_calls_list = [['E-BOOST_combined_text.txt',
  'EDF-2025-LS-DA-SME-NT_combined_text.txt',
  'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
  'FABRIX_combined_text.txt',
  'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
  'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
  'Ukraine-Ready4EU_combined_text.txt',
  'UP-RISE_combined_text.txt'],
 ['CERV-2025-CHILD_combined_text.txt',
  'CERV-2025-CITIZENS-CIV_combined_text.txt',
  'CREA-CROSS-2025-INNOVLAB_combined_text.txt',
  'CREA-MEDIA-2025-CINNET_combined_text.txt',
  'CREA-MEDIA-2025-FILMDIST_combined_text.txt',
  'CREA-MEDIA-2025-FILMOVE_combined_text.txt',
  'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
  'EDF-2025-LS-DA-SME-NT_combined_text.txt',
  'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
  'ERA4Health_combined_text.txt',
  'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt',
  'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt',
  'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt',
  'ESC-HUMAID-2025-VOLUN_combined_text.txt',
  'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
  'ESF-2025-EURES-CBC_combined_text.txt',
  'EUBA-EFSA-2025-PREV-02_combined_text.txt',
  'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
  'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
  'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
  'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
  'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
  'JUST-2025-JCOO_combined_text.txt',
  'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt',
  'PPPA-2025-COUNSEL_combined_text.txt',
  'RFCS-2025-CSP_combined_text.txt',
  'RFCS-2025-JT_combined_text.txt',
  'SOCPL-2025-INFO-WK_combined_text.txt',
  'UCPM-2025-KAPP-EX_combined_text.txt',
  'UCPM-2025-TRACK1_combined_text.txt'],
 ['CREA-CROSS-2025-INNOVLAB_combined_text.txt',
  'CREA-MEDIA-2025-CINNET_combined_text.txt',
  'CREA-MEDIA-2025-FILMDIST_combined_text.txt',
  'CREA-MEDIA-2025-FILMOVE_combined_text.txt',
  'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
  'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
  'EDF-2025-LS-DA-SME-NT_combined_text.txt',
  'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
  'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'ESC-HUMAID-2025-VOLUN_combined_text.txt',
  'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
  'ESF-2025-EURES-CBC_combined_text.txt',
  'EUBA-EFSA-2025-PREV-02_combined_text.txt',
  'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
  'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
  'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
  'RFCS-2025-CSP_combined_text.txt',
  'UCPM-2025-KAPP-EX_combined_text.txt'],
 ['ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
  'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
  'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt'],
 ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
  'EDF-2025-LS-DA-SME-NT_combined_text.txt',
  'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
  'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt',
  'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'ESC-HUMAID-2025-VOLUN_combined_text.txt',
  'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
  'ESF-2025-EURES-CBC_combined_text.txt',
  'EUBA-EFSA-2025-PREV-02_combined_text.txt',
  'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
  'PPPA-2025-COUNSEL_combined_text.txt',
  'RFCS-2025-CSP_combined_text.txt',
  'UCPM-2025-KAPP-EX_combined_text.txt'],
 ['CERV-2025-CHILD_combined_text.txt',
  'CREA-CROSS-2025-INNOVLAB_combined_text.txt',
  'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
  'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
  'EDF-2025-LS-DA-SME-NT_combined_text.txt',
  'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
  'ERA4Health_combined_text.txt',
  'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'ESC-HUMAID-2025-VOLUN_combined_text.txt',
  'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
  'ESF-2025-EURES-CBC_combined_text.txt',
  'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
  'EUBA-EFSA-2025-PREV-02_combined_text.txt',
  'FRONTIERS_combined_text.txt',
  'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
  'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
  'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
  'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
  'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
  'NGI0_Commons_Fund_combined_text.txt',
  'PPPA-2025-COUNSEL_combined_text.txt',
  'RFCS-2025-CSP_combined_text.txt',
  'RFCS-2025-JT_combined_text.txt',
  'UCPM-2025-KAPP-EX_combined_text.txt',
  'UP-RISE_combined_text.txt'],
 ['COPILOT_combined_text.txt',
  'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
  'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
  'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
  'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
  'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt'],
 ['CERV-2025-CHILD_combined_text.txt',
  'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
  'EDF-2025-LS-DA-SME-NT_combined_text.txt',
  'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
  'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt',
  'ESC-HUMAID-2025-VOLUN_combined_text.txt',
  'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
  'ESF-2025-EURES-CBC_combined_text.txt',
  'EUBA-EFSA-2025-PREV-02_combined_text.txt',
  'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
  'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
  'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
  'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
  'PPPA-2025-COUNSEL_combined_text.txt',
  'RFCS-2025-CSP_combined_text.txt',
  'UCPM-2025-KAPP-EX_combined_text.txt',
  'UCPM-2025-TRACK1_combined_text.txt'],
 ['CERV-2025-CHILD_combined_text.txt',
  'COPILOT_combined_text.txt',
  'CREA-CROSS-2025-INNOVLAB_combined_text.txt',
  'CREA-MEDIA-2025-CINNET_combined_text.txt',
  'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
  'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
  'EDF-2025-LS-DA-SME-NT_combined_text.txt',
  'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
  'ERA4Health_combined_text.txt',
  'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'ESC-HUMAID-2025-VOLUN_combined_text.txt',
  'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
  'ESF-2025-EURES-CBC_combined_text.txt',
  'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
  'EUBA-EFSA-2025-PREV-02_combined_text.txt',
  'FRONTIERS_combined_text.txt',
  'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
  'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
  'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
  'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
  'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
  'NGI0_Commons_Fund_combined_text.txt',
  'PPPA-2025-COUNSEL_combined_text.txt',
  'PPPA-2025-DEPLAN_combined_text.txt',
  'RFCS-2025-CSP_combined_text.txt',
  'RFCS-2025-JT_combined_text.txt',
  'SOCPL-2025-INFO-WK_combined_text.txt',
  'UCPM-2025-KAPP-EX_combined_text.txt',
  'UP-RISE_combined_text.txt'],
 ['CERV-2025-CHILD_combined_text.txt',
  'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
  'EDF-2025-LS-DA-SME-NT_combined_text.txt',
  'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
  'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'ESC-HUMAID-2025-VOLUN_combined_text.txt',
  'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
  'ESF-2025-EURES-CBC_combined_text.txt',
  'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
  'EUBA-EFSA-2025-PREV-02_combined_text.txt',
  'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
  'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
  'PPPA-2025-COUNSEL_combined_text.txt',
  'RFCS-2025-CSP_combined_text.txt',
  'UCPM-2025-KAPP-EX_combined_text.txt'],
 ['CERV-2025-CHILD_combined_text.txt',
  'CERV-2025-CITIZENS-CIV_combined_text.txt',
  'CREA-CROSS-2025-INNOVLAB_combined_text.txt',
  'CREA-MEDIA-2025-CINNET_combined_text.txt',
  'CREA-MEDIA-2025-FILMDIST_combined_text.txt',
  'CREA-MEDIA-2025-FILMOVE_combined_text.txt',
  'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
  'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
  'E-BOOST_combined_text.txt',
  'EDF-2025-LS-DA-SME-NT_combined_text.txt',
  'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
  'ERA4Health_combined_text.txt',
  'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt',
  'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt',
  'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt',
  'ESC-HUMAID-2025-VOLUN_combined_text.txt',
  'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
  'ESF-2025-EURES-CBC_combined_text.txt',
  'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
  'EUBA-EFSA-2025-PREV-02_combined_text.txt',
  'FRONTIERS_combined_text.txt',
  'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
  'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
  'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
  'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
  'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
  'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt',
  'JUST-2025-JCOO_combined_text.txt',
  'OSCARS_combined_text.txt',
  'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt',
  'PPPA-2025-COUNSEL_combined_text.txt',
  'PPPA-2025-DEPLAN_combined_text.txt',
  'RFCS-2025-CSP_combined_text.txt',
  'RFCS-2025-JT_combined_text.txt',
  'SOCPL-2025-INFO-WK_combined_text.txt',
  'UCPM-2025-KAPP-EX_combined_text.txt',
  'UCPM-2025-TRACK1_combined_text.txt',
  'Ukraine-Ready4EU_combined_text.txt',
  'UP-RISE_combined_text.txt'],
 ['CERV-2025-CHILD_combined_text.txt',
  'COPILOT_combined_text.txt',
  'CREA-CROSS-2025-INNOVLAB_combined_text.txt',
  'CREA-MEDIA-2025-CINNET_combined_text.txt',
  'CREA-MEDIA-2025-FILMOVE_combined_text.txt',
  'CREA-MEDIA-2025-TVONLINE_combined_text.txt',
  'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt',
  'E-BOOST_combined_text.txt',
  'EDF-2025-LS-DA-SME-NT_combined_text.txt',
  'EDF-2025-LS-RA-SMERO-NT_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt',
  'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt',
  'ERA4Health_combined_text.txt',
  'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt',
  'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt',
  'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt',
  'ESC-HUMAID-2025-VOLUN_combined_text.txt',
  'ESF-2025-AG-NETW-MF-SE_combined_text.txt',
  'ESF-2025-EURES-CBC_combined_text.txt',
  'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt',
  'EUBA-EFSA-2025-PREV-02_combined_text.txt',
  'FABRIX_combined_text.txt',
  'FRONTIERS_combined_text.txt',
  'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt',
  'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt',
  'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt',
  'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt',
  'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt',
  'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt',
  'PPPA-2025-COUNSEL_combined_text.txt',
  'RFCS-2025-CSP_combined_text.txt',
  'RFCS-2025-JT_combined_text.txt',
  'SOCPL-2025-INFO-WK_combined_text.txt',
  'UCPM-2025-KAPP-EX_combined_text.txt',
  'UCPM-2025-TRACK1_combined_text.txt',
  'Ukraine-Ready4EU_combined_text.txt',
  'UP-RISE_combined_text.txt']]

# %%
questions = [
    "Which call is primarily targeted at small and medium-sized enterprises (SMEs)?",
    "Which call requires partnership or cooperation among multiple EU member states?",
    "Which call targets the culture and creative sectors (e.g., film, media, arts)?",
    "Which call is designated only for non-profit organizations or NGOs?",
    "Which call supports mobility of students or youth under the Erasmus programme?",
    "Which call focuses on research and development of new technologies or innovations (RIA, POC)?",
    "Which call is funded under a European Joint Undertaking (JU)?",
    "Which call relates to humanitarian aid or civil protection?",
    "Which call includes pilot validation of technology or demonstration projects?",
    "Which call aims to strengthen digital infrastructure or EDIH centres?",
    "Which call is open to applicants from third countries outside the EU/EEA?",
    "Which call requires emphasis on environmental sustainability or clean energy?"
]

questions_string = ""
for i, question in enumerate(questions):
    questions_string += f"{i + 1}. {question}\n"

print(questions_string)
# Out:
# 1. Which call is primarily targeted at small and medium-sized enterprises (SMEs)?
# 2. Which call requires partnership or cooperation among multiple EU member states?
# 3. Which call targets the culture and creative sectors (e.g., film, media, arts)?
# 4. Which call is designated only for non-profit organizations or NGOs?
# 5. Which call supports mobility of students or youth under the Erasmus programme?
# 6. Which call focuses on research and development of new technologies or innovations (RIA, POC)?
# 7. Which call is funded under a European Joint Undertaking (JU)?
# 8. Which call relates to humanitarian aid or civil protection?
# 9. Which call includes pilot validation of technology or demonstration projects?
# 10. Which call aims to strengthen digital infrastructure or EDIH centres?
# 11. Which call is open to applicants from third countries outside the EU/EEA?
# 12. Which call requires emphasis on environmental sustainability or clean energy?

# %%
# --- Hromadné LLM vyhodnocení validních callů pro každou otázku (OPRAVENO) ---
import glob
import json
import google.generativeai as genai
import os
import time

genai.configure(api_key="AIzaSyB3LkpREqIq8WwCFxsjXEd6-2h-Jnu1G7U")
# Načti všechny summary a připrav dictionary {call_name: summary_text}
summary_folder = "./summary"
summary_files = glob.glob(os.path.join(summary_folder, "*_summary.txt"))
all_summaries = {}
for summary_path in summary_files:
    call_name = os.path.basename(summary_path).replace("_summary.txt", "")
    with open(summary_path, "r", encoding="utf-8") as file:
        all_summaries[call_name] = file.read()

def build_llm_prompt_call_list(summaries_dict, question):
    prompt = (
        "You are an expert at finding any possibly relevant project calls.\n"
        "For each CALL below, you will:\n"
        "  1) Think *step by step* whether there is the slightest potential that the answer to the question could be found in its summary.\n"
        "  2) If there is any potential relevance or even the smallest hint or uncertainty, mark it as INCLUDE. Otherwise, mark it as EXCLUDE.\n\n"
        "It is more important to take all pontecial calls. If you are not sure, take that call. \n\n"
        "**** OUTPUT FORMAT ****\n"
        "Return **only** a JSON object where keys are CALL names and values are “INCLUDE” or “EXCLUDE”, e.g.:\n"
        "  {\"CALL1\": \"INCLUDE\", \"CALL2\": \"EXCLUDE\", …}\n\n"
        "Then, in a second JSON list, return **only** the names of the INCLUDED calls, e.g.:\n"
        "  [\"CALL1\", \"CALL5\", …]\n\n"
        "**** DO NOT output any other text or your chain of thought. ****\n\n"
        f"Question:\n{question}\n\n"
        "Summaries:\n"
    )
    for call, summary in summaries_dict.items():
        prompt += f"CALL: {call}\nSUMMARY: {summary}\n\n"
    return prompt



def generate_call_list(prompt, max_retries=5):
    model = genai.GenerativeModel("gemini-2.5-flash-preview-04-17")
    retries = 0
    while retries < max_retries:
        try:
            response = model.generate_content(prompt)
            # Najdi první a poslední hranatou závorku a zkus to zparsovat jako list
            json_start = response.text.find('[')
            json_end = response.text.rfind(']') + 1
            json_str = response.text[json_start:json_end]
            parsed = json.loads(json_str)
            return parsed
        except Exception as e:
            retries += 1
            wait_time = 2 ** retries
            print(f"Retry {retries}/{max_retries} after error: {e}. Waiting {wait_time} seconds.")
            time.sleep(wait_time)
    print("Max retries reached. Returning None.")
    return None

llm_summary_answers = [[] for _ in range(len(questions))]

for q_idx, question in enumerate(questions):
    prompt = build_llm_prompt_call_list(all_summaries, question)
    response = generate_call_list(prompt, max_retries=3)
    print(f"LLM response for question {q_idx+1}: {response}")
    if response:
        llm_summary_answers[q_idx] = [f"{call}_combined_text.txt" for call in response]

from sklearn.metrics import precision_score, recall_score, f1_score

# Vyhodnocení precision, recall, F1 pro každou otázku
for q_idx, question in enumerate(questions):
    y_true = []
    y_pred = []
    all_calls = set(answers[q_idx]) | set(llm_summary_answers[q_idx])
    for call in all_calls:
        y_true.append(1 if call in answers[q_idx] else 0)
        y_pred.append(1 if call in llm_summary_answers[q_idx] else 0)
    if len(set(y_true)) > 1:  # musí být aspoň jeden true a jeden false
        precision = precision_score(y_true, y_pred)
        recall = recall_score(y_true, y_pred)
        f1 = f1_score(y_true, y_pred)
    else:
        precision = recall = f1 = float('nan')
    print(f"Otázka {q_idx+1}: {question}")
    print(f"Precision: {precision:.2f}, Recall: {recall:.2f}, F1: {f1:.2f}\n")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 64
#      62 for q_idx, question in enumerate(questions):
#      63     prompt = build_llm_prompt_call_list(all_summaries, question)
# ---> 64     response = generate_call_list(prompt, max_retries=3)
#      65     print(f"LLM response for question {q_idx+1}: {response}")
#      66     if response:
#
# Cell In[4], line 45, in generate_call_list(prompt, max_retries)
#      43 while retries < max_retries:
#      44     try:
# ---> 45         response = model.generate_content(prompt)
#      46         # Najdi první a poslední hranatou závorku a zkus to zparsovat jako list
#      47         json_start = response.text.find('[')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\generativeai\generative_models.py:331, in GenerativeModel.generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329         return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330     else:
# --> 331         response = self._client.generate_content(
#     332             request,
#     333             **request_options,
#     334         )
#     335         return generation_types.GenerateContentResponse.from_response(response)
#     336 except google.api_core.exceptions.InvalidArgument as e:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\client.py:835, in GenerativeServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#     832 self._validate_universe_domain()
#     834 # Send the request.
# --> 835 response = rpc(
#     836     request,
#     837     retry=retry,
#     838     timeout=timeout,
#     839     metadata=metadata,
#     840 )
#     842 # Done; return the response.
#     843 return response
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\api_core\gapic_v1\method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\api_core\retry\retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\api_core\retry\retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\api_core\timeout.py:130, in TimeToDeadlineTimeout.__call__.<locals>.func_with_timeout(*args, **kwargs)
#     126         remaining_timeout = self._timeout
#     128     kwargs["timeout"] = remaining_timeout
# --> 130 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\api_core\grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File ~\AppData\Roaming\Python\Python312\site-packages\grpc\_interceptor.py:277, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     268 def __call__(
#     269     self,
#     270     request: Any,
#    (...)
#     275     compression: Optional[grpc.Compression] = None,
#     276 ) -> Any:
# --> 277     response, ignored_call = self._with_call(
#     278         request,
#     279         timeout=timeout,
#     280         metadata=metadata,
#     281         credentials=credentials,
#     282         wait_for_ready=wait_for_ready,
#     283         compression=compression,
#     284     )
#     285     return response
#
# File ~\AppData\Roaming\Python\Python312\site-packages\grpc\_interceptor.py:329, in _UnaryUnaryMultiCallable._with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     326     except Exception as exception:  # pylint:disable=broad-except
#     327         return _FailureOutcome(exception, sys.exc_info()[2])
# --> 329 call = self._interceptor.intercept_unary_unary(
#     330     continuation, client_call_details, request
#     331 )
#     332 return call.result(), call
#
# File ~\AppData\Roaming\Python\Python312\site-packages\google\ai\generativelanguage_v1beta\services\generative_service\transports\grpc.py:79, in _LoggingClientInterceptor.intercept_unary_unary(self, continuation, client_call_details, request)
#      64     grpc_request = {
#      65         "payload": request_payload,
#      66         "requestMethod": "grpc",
#      67         "metadata": dict(request_metadata),
#      68     }
#      69     _LOGGER.debug(
#      70         f"Sending request for {client_call_details.method}",
#      71         extra={
#    (...)
#      76         },
#      77     )
# ---> 79 response = continuation(client_call_details, request)
#      80 if logging_enabled:  # pragma: NO COVER
#      81     response_metadata = response.trailing_metadata()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\grpc\_interceptor.py:315, in _UnaryUnaryMultiCallable._with_call.<locals>.continuation(new_details, request)
#     306 (
#     307     new_method,
#     308     new_timeout,
#    (...)
#     312     new_compression,
#     313 ) = _unwrap_client_call_details(new_details, client_call_details)
#     314 try:
# --> 315     response, call = self._thunk(new_method).with_call(
#     316         request,
#     317         timeout=new_timeout,
#     318         metadata=new_metadata,
#     319         credentials=new_credentials,
#     320         wait_for_ready=new_wait_for_ready,
#     321         compression=new_compression,
#     322     )
#     323     return _UnaryOutcome(response, call)
#     324 except grpc.RpcError as rpc_error:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\grpc\_channel.py:1195, in _UnaryUnaryMultiCallable.with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1183 def with_call(
#    1184     self,
#    1185     request: Any,
#    (...)
#    1190     compression: Optional[grpc.Compression] = None,
#    1191 ) -> Tuple[Any, grpc.Call]:
#    1192     (
#    1193         state,
#    1194         call,
# -> 1195     ) = self._blocking(
#    1196         request, timeout, metadata, credentials, wait_for_ready, compression
#    1197     )
#    1198     return _end_unary_response_blocking(state, call, True, None)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\grpc\_channel.py:1162, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1145 state.target = _common.decode(self._target)
#    1146 call = self._channel.segregated_call(
#    1147     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1148     self._method,
#    (...)
#    1160     self._registered_call_handle,
#    1161 )
# -> 1162 event = call.next_event()
#    1163 _handle_event(event, state, self._response_deserializer)
#    1164 return state, call
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:388, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:211, in grpc._cython.cygrpc._next_call_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/channel.pyx.pxi:205, in grpc._cython.cygrpc._next_call_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src\\python\\grpcio\\grpc\\_cython\\_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %%
# --- Vektorizace a rozšíření výběru callů podle embeddingů + vyhodnocení metrik ---
import glob
import os
import torch
from tqdm import tqdm
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics import precision_score, recall_score, f1_score

# 1. Načti všechny combined_text soubory a rozděl na chunk(y)
data_folder = './data'
combined_files = glob.glob(os.path.join(data_folder, '*_combined_text.txt'))
chunk_size = 512  # znaků na chunk, lze upravit
chunks = []  # [(call_name, chunk_text)]
for file_path in tqdm(combined_files):
    call_name = os.path.basename(file_path).replace('_combined_text.txt', '')
    with open(file_path, 'r', encoding='utf-8') as f:
        text = f.read()
    for i in range(0, len(text), chunk_size):
        chunk = text[i:i+chunk_size]
        chunks.append((call_name, chunk))

# 2. Vygeneruj embeddingy pro všechny chunk(y) pomocí intfloat/multilingual-e5-base na GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = SentenceTransformer('intfloat/multilingual-e5-base', device=device)
chunk_texts = [c[1] for c in chunks]
chunk_embeddings = model.encode(
    chunk_texts, batch_size=32, show_progress_bar=True, convert_to_tensor=True, normalize_embeddings=True, device=device
)

# 3. Vygeneruj embedding pro otázku
question_embedding = model.encode([question], convert_to_tensor=True, normalize_embeddings=True, device=device)[0]

# 4. Najdi 10 nejbližších chunků
cos_scores = util.pytorch_cos_sim(question_embedding, chunk_embeddings)[0]
top_k = min(10, len(chunks))
top_results = cos_scores.topk(top_k)

# 5. Získej názvy callů těchto chunků
nearest_calls = set()
for idx in top_results.indices.tolist():
    nearest_calls.add(chunks[idx][0])

print('10 nejbližších callů podle embeddingů:', nearest_calls)

# 6. Přidej tyto call names do seznamu doporučených callů (pokud už tam nejsou)
# Odpovědi z LLM jsou již v answers
llm_calls = set([c.replace('_combined_text.txt', '') for c in answers[q_idx]])
all_recommended_calls = llm_calls | nearest_calls
print('Kombinovaný výběr callů:', all_recommended_calls)

# 7. Vyhodnocení metrik pro kombinovaný výběr
y_true = []
y_pred = []
all_calls = set(answers[q_idx]) | set([f'{c}_combined_text.txt' for c in all_recommended_calls])
for call in all_calls:
    y_true.append(1 if call in answers[q_idx] else 0)
    y_pred.append(1 if call.replace('_combined_text.txt','') in all_recommended_calls else 0)
if len(set(y_true)) > 1:
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
else:
    precision = recall = f1 = float('nan')
print(f'Kombinovaný výběr - Precision: {precision:.2f}, Recall: {recall:.2f}, F1: {f1:.2f}')

# Pokud chceš, můžeš vytvořit nový seznam souborů pro další použití:
combined_llm_rag_answers = [f'{call}_combined_text.txt' for call in all_recommended_calls]
# Out:
# 100%|██████████| 64/64 [00:00<00:00, 94.79it/s]
# Batches:   0%|          | 0/7903 [00:00<?, ?it/s]
# 10 nejbližších callů podle embeddingů: {'HORIZON-JU-CBE-2025-CSA-01', 'HORIZON-JU-CBE-2025-IAFlag-03', 'CREA-CROSS-2025-INNOVLAB', 'HORIZON-JU-CBE-2025-RIA-02', 'EDF-2025-LS-RA-SMERO-NT', 'RFCS-2025-JT', 'FABRIX', 'ERASMUS-YOUTH-2025-CSC-OG-FPA', 'HORIZON-MSCA-2025-COFUND-01-01'}
# Kombinovaný výběr callů: {'HORIZON-JU-CBE-2025-CSA-01', 'Ukraine-Ready4EU', 'E-BOOST', 'CREA-CROSS-2025-INNOVLAB', 'HORIZON-JU-CBE-2025-RIA-02', 'ERASMUS-YOUTH-2025-CSC-OG-FPA', 'EDF-2025-LS-RA-SMERO-NT', 'UP-RISE', 'EDF-2025-LS-DA-SME-NT', 'RFCS-2025-JT', 'FABRIX', 'HORIZON-JU-CBE-2025-IAFlag-03', 'HORIZON-MSCA-2025-COFUND-01-01'}
# Kombinovaný výběr - Precision: 0.62, Recall: 1.00, F1: 0.76

# %%
import torch
from sentence_transformers import util
from sklearn.metrics import precision_score, recall_score, f1_score

# --- 1) Nahraj svoje data ---
# chunks, chunk_embeddings, model, questions a true_calls_list máš z předchozího skriptu

# 2) Tvoje LLM odpovědi:
llm_responses = [
    ['COPILOT', 'E-BOOST', 'EDF-2025-LS-DA-SME-NT', 'EDF-2025-LS-RA-SMERO-NT', 'HORIZON-EIC-2025-EICSTEP-01', 'NGI0_Commons_Fund', 'Ukraine-Ready4EU', 'UP-RISE'],
    ['CERV-2025-CHILD', 'CERV-2025-CITIZENS-CIV', 'CREA-CROSS-2025-INNOVLAB', 'CREA-MEDIA-2025-CINNET', 'CREA-MEDIA-2025-FILMOVE', 'CREA-MEDIA-2025-TVONLINE', 'EDF-2025-CSA-NFP', 'EDF-2025-LS-DA-SME-NT', 'EDF-2025-LS-RA-SMERO-NT', 'ERA4Health', 'ERASMUS-EDU-2025-CSC-OG-FPA', 'ERASMUS-EDU-2025-PEX-COVE', 'ERASMUS-YOUTH-2025-CSC-OG-FPA', 'ESF-2025-AG-NETW-MF-SE', 'ESF-2025-EURES-CBC', 'ESF-2025-OG-NETW-NGO-FPA', 'ESF-2025-OG-NETW-NGO-SGA', 'JUST-2025-JCOO-JACC-OG-FPA', 'JUST-2025-JCOO-JACC-OG-SGA', 'JUST-2025-JCOO', 'PPPA-2025-COUNSEL', 'PPPA-2025-DEPLAN', 'RFCS-2025-CSP', 'RFCS-2025-JT', 'SMP-CONS-2025-ADR-RAD', 'SOCPL-2025-INFO-WK', 'UCPM-2025-KAPP-EX', 'UCPM-2025-KAPP-PVPP'],
    ['CREA-CROSS-2025-INNOVLAB', 'CREA-MEDIA-2025-CINNET', 'CREA-MEDIA-2025-FILMDIST', 'CREA-MEDIA-2025-FILMOVE', 'CREA-MEDIA-2025-TRAINING', 'CREA-MEDIA-2025-TVONLINE'],
    ['ERASMUS-EDU-2025-CSC-OG-FPA', 'ERASMUS-YOUTH-2025-CSC-OG-FPA', 'ESF-2025-AG-NETW-MF-SE', 'ESF-2025-OG-NETW-NGO-FPA', 'ESF-2025-OG-NETW-NGO-SGA', 'JUST-2025-JCOO-JACC-OG-FPA', 'JUST-2025-JCOO-JACC-OG-SGA'],
    ['DigiQ', 'EP-LINC-SUBV-2025-CONF-INT-01', 'EP-LINC-SUBV-2025-CONF-INT-02', 'EP-LINC-SUBV-2025-CONF-INT-03', 'ERASMUS-EDU-2022-ECHE-CERT-FP', 'ERASMUS-EDU-2025-CSC-OG-FPA', 'ERASMUS-EDU-2025-PEX-COVE', 'ERASMUS-YOUTH-2025-CSC-OG-FPA', 'ESC-HUMAID-2021-QUAL-LABEL-FP', 'ESC-HUMAID-2025-VOLUN', 'HORIZON-JU-CLEANH2-2025-01-03', 'HORIZON-JU-CLEANH2-2025-02-01', 'HORIZON-MSCA-2025-COFUND-01-01'],
    ['COPILOT', 'CREA-CROSS-2025-INNOVLAB', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP', 'E-BOOST', 'EDF-2025-LS-DA-SME-NT', 'EDF-2025-LS-RA-SMERO-NT', 'EP-LINC-SUBV-2025-CONF-INT-01', 'EP-LINC-SUBV-2025-CONF-INT-02', 'ERASMUS-EDU-2025-PEX-COVE', 'HORIZON-EIC-2025-ACCELERATOR-01', 'HORIZON-EIC-2025-EICSTEP-01', 'HORIZON-MSCA-2025-COFUND-01-01', 'INNOVFUND-2024-BATT-EV-CELLS', 'NGI0_Commons_Fund', 'OSCARS', 'PPPA-2025-DEPLAN', 'RFCS-2025-CSP', 'RFCS-2025-JT', 'UP-RISE'],
    ['COPILOT', 'HORIZON-JU-CBE-2025-CSA-01', 'HORIZON-JU-CBE-2025-IAFlag-03', 'HORIZON-JU-CBE-2025-RIA-02', 'HORIZON-JU-CLEANH2-2025-01-03', 'HORIZON-JU-CLEANH2-2025-01-06', 'HORIZON-JU-CLEANH2-2025-02-01'],
    ['ESC-HUMAID-2021-QUAL-LABEL-FP', 'ESC-HUMAID-2025-VOLUN', 'UCPM-2025-KAPP-EX', 'UCPM-2025-KAPP-PVPP', 'UCPM-2025-TRACK1'],
    ['CREA-CROSS-2025-INNOVLAB', 'CREA-MEDIA-2025-CINNET', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP', 'EDF-2025-LS-DA-SME-NT', 'ERA4Health', 'ERC-2025-POC', 'FABRIX', 'HORIZON-EIC-2025-ACCELERATOR-01', 'HORIZON-EIC-2025-EICSTEP-01', 'HORIZON-JU-CLEANH2-2025-01-03', 'HORIZON-JU-CLEANH2-2025-02-01', 'INNOVFUND-2024-BATT-EV-CELLS', 'NGI0_Commons_Fund', 'OSCARS', 'PPPA-2025-DEPLAN', 'RFCS-2025-CSP', 'RFCS-2025-JT', 'UCPM-2025-KAPP-PVPP', 'UP-RISE'],
    ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP', 'NGI0_Commons_Fund', 'OSCARS'],
    ['CERV-2025-CHILD', 'CERV-2025-CITIZENS-CIV', 'CERV-2025-DAPHNE', 'Connecting_Spheres', 'COPILOT', 'CREA-CROSS-2025-INNOVLAB', 'CREA-MEDIA-2025-CINNET', 'CREA-MEDIA-2025-FILMDIST', 'CREA-MEDIA-2025-FILMOVE', 'CREA-MEDIA-2025-TRAINING', 'CREA-MEDIA-2025-TVONLINE', 'DigiQ', 'E-BOOST', 'EDF-2025-CSA-NFP', 'EDF-2025-LS-DA-SME-NT', 'EDF-2025-LS-RA-SMERO-NT', 'EP-LINC-SUBV-2025-CONF-INT-01', 'EP-LINC-SUBV-2025-CONF-INT-02', 'EP-LINC-SUBV-2025-CONF-INT-03', 'ERA4Health', 'ERASMUS-EDU-2022-ECHE-CERT-FP', 'ERASMUS-EDU-2025-CSC-OG-FPA', 'ERASMUS-EDU-2025-PEX-COVE', 'ERASMUS-YOUTH-2025-CSC-OG-FPA', 'ERC-2025-POC', 'ESC-HUMAID-2021-QUAL-LABEL-FP', 'ESC-HUMAID-2025-VOLUN', 'ESF-2025-AG-NETW-MF-SE', 'ESF-2025-OG-NETW-NGO-FPA', 'ESF-2025-OG-NETW-NGO-SGA', 'FRONTIERS', 'HORIZON-EIC-2025-ACCELERATOR-01', 'HORIZON-EIC-2025-EICSTEP-01', 'HORIZON-JU-CLEANH2-2025-01-03', 'HORIZON-MSCA-2025-COFUND-01-01', 'INNOVFUND-2024-BATT-EV-CELLS', 'JUST-2025-JCOO-JACC-OG-FPA', 'JUST-2025-JCOO-JACC-OG-SGA', 'JUST-2025-JCOO', 'NGI0_Commons_Fund', 'OSCARS', 'PPPA-2025-COUNSEL', 'RFCS-2025-CSP', 'RFCS-2025-JT', 'SMP-CONS-2025-ADR-RAD', 'SOCPL-2025-INFO-WK', 'UCPM-2025-KAPP-EX', 'UCPM-2025-KAPP-PVPP', 'UCPM-2025-TRACK1', 'Ukraine-Ready4EU', 'UP-RISE'],
    ['Connecting_Spheres', 'COPILOT', 'CREA-CROSS-2025-INNOVLAB', 'CREA-MEDIA-2025-CINNET', 'CREA-MEDIA-2025-TRAINING', 'CREA-MEDIA-2025-TVONLINE', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP', 'E-BOOST', 'ERASMUS-EDU-2022-ECHE-CERT-FP', 'ERASMUS-EDU-2025-CSC-OG-FPA', 'ERASMUS-YOUTH-2025-CSC-OG-FPA', 'ESC-HUMAID-2021-QUAL-LABEL-FP', 'ESC-HUMAID-2025-VOLUN', 'ESF-2025-EURES-CBC', 'FABRIX', 'HORIZON-EIC-2025-ACCELERATOR-01', 'HORIZON-EIC-2025-EICSTEP-01', 'HORIZON-JU-CBE-2025-CSA-01', 'HORIZON-JU-CBE-2025-IAFlag-03', 'HORIZON-JU-CBE-2025-RIA-02', 'HORIZON-JU-CLEANH2-2025-01-03', 'HORIZON-JU-CLEANH2-2025-01-06', 'HORIZON-JU-CLEANH2-2025-02-01', 'INNOVFUND-2024-BATT-EV-CELLS', 'RFCS-2025-CSP', 'RFCS-2025-JT', 'UCPM-2025-KAPP-EX', 'UCPM-2025-KAPP-PVPP', 'UCPM-2025-TRACK1', 'Ukraine-Ready4EU']
]

device = chunk_embeddings.device

# Nastav si tady, kolik nearest calls chceš pro každý dotaz:
k = 40

# 2) Embeduj otázky
question_embeddings = model.encode(
    questions,
    batch_size=32,
    show_progress_bar=True,
    convert_to_tensor=True,
    normalize_embeddings=True,
    device=device
)

results = []
for idx, q_emb in enumerate(question_embeddings):
    # RAG retrieval: bereme top-k
    scores = util.pytorch_cos_sim(q_emb, chunk_embeddings)[0]
    topk = scores.topk(min(k, scores.size(0)))
    nearest_raw = [chunks[i][0] for i in topk.indices.tolist()]
    nearest_calls = {name + '_combined_text.txt' for name in nearest_raw}

    # LLM odpověď
    llm_calls = {name + '_combined_text.txt' for name in llm_responses[idx]}

    # Ground-truth
    true_calls = set(true_calls_list[idx])

    # Sjednocení a průnik
    combined_calls = true_calls | nearest_calls | llm_calls
    correct_calls  = true_calls & (nearest_calls | llm_calls)

    # Připrav labely pro metriky
    all_calls = list(combined_calls)
    y_true = [1 if c in true_calls else 0 for c in all_calls]
    y_pred = [1 if c in (nearest_calls | llm_calls) else 0 for c in all_calls]

    # Spočti precision, recall, f1
    if len(set(y_true)) > 1:
        p = precision_score(y_true, y_pred)
        r = recall_score(y_true, y_pred)
        f1 = f1_score(y_true, y_pred)
    else:
        p = r = f1 = float('nan')

    results.append({
        'question'       : questions[idx],
        'true_calls'     : sorted(true_calls),
        'nearest_calls'  : sorted(nearest_calls),
        'llm_calls'      : sorted(llm_calls),
        'combined_calls' : sorted(combined_calls),
        'correct_calls'  : sorted(correct_calls),
        'precision'      : p,
        'recall'         : r,
        'f1'             : f1
    })

# 3) Výpis všech informací
for res in results:
    print(f"Otázka: {res['question']}")
    print(f"  True calls:      {res['true_calls']}")
    print(f"  Nearest {k} calls: {res['nearest_calls']}")
    print(f"  LLM calls:       {res['llm_calls']}")
    print(f"  Combined calls:  {res['combined_calls']}")
    print(f"  Correct calls:   {res['correct_calls']}")
    print(f"  Precision: {res['precision']:.2f}, Recall: {res['recall']:.2f}, F1: {res['f1']:.2f}\n")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Otázka: Which call is primarily targeted at small and medium-sized enterprises (SMEs)?
#   True calls:      ['E-BOOST_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'FABRIX_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'UP-RISE_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Nearest 40 calls: ['CERV-2025-CITIZENS-CIV_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'FABRIX_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   LLM calls:       ['COPILOT_combined_text.txt', 'E-BOOST_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'UP-RISE_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Combined calls:  ['CERV-2025-CITIZENS-CIV_combined_text.txt', 'COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'E-BOOST_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'FABRIX_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt', 'UP-RISE_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Correct calls:   ['E-BOOST_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'FABRIX_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'UP-RISE_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Precision: 0.22, Recall: 1.00, F1: 0.36
#
# Otázka: Which call requires partnership or cooperation among multiple EU member states?
#   True calls:      ['CERV-2025-CHILD_combined_text.txt', 'CERV-2025-CITIZENS-CIV_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'JUST-2025-JCOO_combined_text.txt', 'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   Nearest 40 calls: ['EDF-2025-CSA-NFP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   LLM calls:       ['CERV-2025-CHILD_combined_text.txt', 'CERV-2025-CITIZENS-CIV_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'EDF-2025-CSA-NFP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'JUST-2025-JCOO_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SMP-CONS-2025-ADR-RAD_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt']
#   Combined calls:  ['CERV-2025-CHILD_combined_text.txt', 'CERV-2025-CITIZENS-CIV_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'EDF-2025-CSA-NFP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'JUST-2025-JCOO_combined_text.txt', 'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SMP-CONS-2025-ADR-RAD_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   Correct calls:   ['CERV-2025-CHILD_combined_text.txt', 'CERV-2025-CITIZENS-CIV_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'JUST-2025-JCOO_combined_text.txt', 'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   Precision: 0.68, Recall: 0.82, F1: 0.74
#
# Otázka: Which call targets the culture and creative sectors (e.g., film, media, arts)?
#   True calls:      ['CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt']
#   Nearest 40 calls: ['CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt']
#   LLM calls:       ['CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt']
#   Combined calls:  ['CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt']
#   Correct calls:   ['CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt']
#   Precision: 0.82, Recall: 0.43, F1: 0.56
#
# Otázka: Which call is designated only for non-profit organizations or NGOs?
#   True calls:      ['ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt']
#   Nearest 40 calls: ['CERV-2025-DAPHNE_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SMP-CONS-2025-ADR-RAD_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   LLM calls:       ['ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt']
#   Combined calls:  ['CERV-2025-DAPHNE_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SMP-CONS-2025-ADR-RAD_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   Correct calls:   ['ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt']
#   Precision: 0.09, Recall: 0.75, F1: 0.17
#
# Otázka: Which call supports mobility of students or youth under the Erasmus programme?
#   True calls:      ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt']
#   Nearest 40 calls: ['ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt']
#   LLM calls:       ['DigiQ_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt']
#   Combined calls:  ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'DigiQ_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt']
#   Correct calls:   ['EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt']
#   Precision: 0.44, Recall: 0.50, F1: 0.47
#
# Otázka: Which call focuses on research and development of new technologies or innovations (RIA, POC)?
#   True calls:      ['CERV-2025-CHILD_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'FRONTIERS_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UP-RISE_combined_text.txt']
#   Nearest 40 calls: ['CERV-2025-DAPHNE_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt']
#   LLM calls:       ['COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'E-BOOST_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'OSCARS_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'UP-RISE_combined_text.txt']
#   Combined calls:  ['CERV-2025-CHILD_combined_text.txt', 'CERV-2025-DAPHNE_combined_text.txt', 'COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'E-BOOST_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'FRONTIERS_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'OSCARS_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UP-RISE_combined_text.txt']
#   Correct calls:   ['CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'UP-RISE_combined_text.txt']
#   Precision: 0.64, Recall: 0.60, F1: 0.62
#
# Otázka: Which call is funded under a European Joint Undertaking (JU)?
#   True calls:      ['COPILOT_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt']
#   Nearest 40 calls: ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'JUST-2025-JCOO_combined_text.txt', 'OSCARS_combined_text.txt']
#   LLM calls:       ['COPILOT_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt']
#   Combined calls:  ['COPILOT_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'JUST-2025-JCOO_combined_text.txt', 'OSCARS_combined_text.txt']
#   Correct calls:   ['COPILOT_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt']
#   Precision: 0.50, Recall: 0.89, F1: 0.64
#
# Otázka: Which call relates to humanitarian aid or civil protection?
#   True calls:      ['CERV-2025-CHILD_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   Nearest 40 calls: ['CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-CSA-NFP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'OSCARS_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   LLM calls:       ['ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   Combined calls:  ['CERV-2025-CHILD_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-CSA-NFP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'OSCARS_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   Correct calls:   ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt']
#   Precision: 0.48, Recall: 0.59, F1: 0.53
#
# Otázka: Which call includes pilot validation of technology or demonstration projects?
#   True calls:      ['CERV-2025-CHILD_combined_text.txt', 'COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'FRONTIERS_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UP-RISE_combined_text.txt']
#   Nearest 40 calls: ['EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt']
#   LLM calls:       ['CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'FABRIX_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'OSCARS_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UP-RISE_combined_text.txt']
#   Combined calls:  ['CERV-2025-CHILD_combined_text.txt', 'COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'FABRIX_combined_text.txt', 'FRONTIERS_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'OSCARS_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UP-RISE_combined_text.txt']
#   Correct calls:   ['CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UP-RISE_combined_text.txt']
#   Precision: 0.74, Recall: 0.68, F1: 0.71
#
# Otázka: Which call aims to strengthen digital infrastructure or EDIH centres?
#   True calls:      ['CERV-2025-CHILD_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt']
#   Nearest 40 calls: ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt']
#   LLM calls:       ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'OSCARS_combined_text.txt']
#   Combined calls:  ['CERV-2025-CHILD_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'OSCARS_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt']
#   Correct calls:   ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt']
#   Precision: 0.50, Recall: 0.11, F1: 0.18
#
# Otázka: Which call is open to applicants from third countries outside the EU/EEA?
#   True calls:      ['CERV-2025-CHILD_combined_text.txt', 'CERV-2025-CITIZENS-CIV_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'E-BOOST_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'FRONTIERS_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO_combined_text.txt', 'OSCARS_combined_text.txt', 'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt', 'UP-RISE_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Nearest 40 calls: ['CERV-2025-DAPHNE_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'EDF-2025-CSA-NFP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'SMP-CONS-2025-ADR-RAD_combined_text.txt']
#   LLM calls:       ['CERV-2025-CHILD_combined_text.txt', 'CERV-2025-CITIZENS-CIV_combined_text.txt', 'CERV-2025-DAPHNE_combined_text.txt', 'COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'Connecting_Spheres_combined_text.txt', 'DigiQ_combined_text.txt', 'E-BOOST_combined_text.txt', 'EDF-2025-CSA-NFP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'FRONTIERS_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'JUST-2025-JCOO_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'OSCARS_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SMP-CONS-2025-ADR-RAD_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt', 'UP-RISE_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Combined calls:  ['CERV-2025-CHILD_combined_text.txt', 'CERV-2025-CITIZENS-CIV_combined_text.txt', 'CERV-2025-DAPHNE_combined_text.txt', 'COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'Connecting_Spheres_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'DigiQ_combined_text.txt', 'E-BOOST_combined_text.txt', 'EDF-2025-CSA-NFP_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ERC-2025-POC_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'ESF-2025-OG-NETW-NGO-SGA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'FRONTIERS_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-MSCA-2025-COFUND-01-01_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-SGA_combined_text.txt', 'JUST-2025-JCOO_combined_text.txt', 'NGI0_Commons_Fund_combined_text.txt', 'OSCARS_combined_text.txt', 'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SMP-CONS-2025-ADR-RAD_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt', 'UP-RISE_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Correct calls:   ['CERV-2025-CHILD_combined_text.txt', 'CERV-2025-CITIZENS-CIV_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMDIST_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'E-BOOST_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'FRONTIERS_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'JUST-2025-JCOO-JACC-OG-FPA_combined_text.txt', 'JUST-2025-JCOO_combined_text.txt', 'OSCARS_combined_text.txt', 'PERI-2025-ANTI-COUNTERFEIT_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'PPPA-2025-DEPLAN_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt', 'UP-RISE_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Precision: 0.70, Recall: 0.96, F1: 0.81
#
# Otázka: Which call requires emphasis on environmental sustainability or clean energy?
#   True calls:      ['CERV-2025-CHILD_combined_text.txt', 'COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'E-BOOST_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'FABRIX_combined_text.txt', 'FRONTIERS_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt', 'UP-RISE_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Nearest 40 calls: ['DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'OSCARS_combined_text.txt']
#   LLM calls:       ['COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'Connecting_Spheres_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'E-BOOST_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'FABRIX_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Combined calls:  ['CERV-2025-CHILD_combined_text.txt', 'COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-FILMOVE_combined_text.txt', 'CREA-MEDIA-2025-TRAINING_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'Connecting_Spheres_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'E-BOOST_combined_text.txt', 'EDF-2025-LS-DA-SME-NT_combined_text.txt', 'EDF-2025-LS-RA-SMERO-NT_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-01_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-02_combined_text.txt', 'EP-LINC-SUBV-2025-CONF-INT-03_combined_text.txt', 'ERA4Health_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ERASMUS-EDU-2025-CSC-OG-FPA_combined_text.txt', 'ERASMUS-EDU-2025-PEX-COVE_combined_text.txt', 'ERASMUS-YOUTH-2025-CSC-OG-FPA_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-AG-NETW-MF-SE_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'ESF-2025-OG-NETW-NGO-FPA_combined_text.txt', 'EUBA-EFSA-2025-PREV-02_combined_text.txt', 'FABRIX_combined_text.txt', 'FRONTIERS_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-06_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-02-01_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'HORIZON-SESAR-2025-DES-ER-03-WA1-1_combined_text.txt', 'INNOVFUND-2024-BATT-EV-CELLS_combined_text.txt', 'OSCARS_combined_text.txt', 'PPPA-2025-COUNSEL_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'SOCPL-2025-INFO-WK_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-KAPP-PVPP_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt', 'UP-RISE_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Correct calls:   ['COPILOT_combined_text.txt', 'CREA-CROSS-2025-INNOVLAB_combined_text.txt', 'CREA-MEDIA-2025-CINNET_combined_text.txt', 'CREA-MEDIA-2025-TVONLINE_combined_text.txt', 'DIGITAL-2025-EDIH-EU-EEA-08-CONSOLIDATION-STEP_combined_text.txt', 'E-BOOST_combined_text.txt', 'ERASMUS-EDU-2022-ECHE-CERT-FP_combined_text.txt', 'ESC-HUMAID-2021-QUAL-LABEL-FP_combined_text.txt', 'ESC-HUMAID-2025-VOLUN_combined_text.txt', 'ESF-2025-EURES-CBC_combined_text.txt', 'FABRIX_combined_text.txt', 'HORIZON-EIC-2025-ACCELERATOR-01_combined_text.txt', 'HORIZON-EIC-2025-EICSTEP-01_combined_text.txt', 'HORIZON-JU-CBE-2025-CSA-01_combined_text.txt', 'HORIZON-JU-CBE-2025-IAFlag-03_combined_text.txt', 'HORIZON-JU-CBE-2025-RIA-02_combined_text.txt', 'HORIZON-JU-CLEANH2-2025-01-03_combined_text.txt', 'HORIZON-JU-IHI-2025-09-01-single-stage_combined_text.txt', 'RFCS-2025-CSP_combined_text.txt', 'RFCS-2025-JT_combined_text.txt', 'UCPM-2025-KAPP-EX_combined_text.txt', 'UCPM-2025-TRACK1_combined_text.txt', 'Ukraine-Ready4EU_combined_text.txt']
#   Precision: 0.70, Recall: 0.59, F1: 0.64

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# Convert embeddings to NumPy (from CPU)
qe = question_embeddings.cpu().numpy()   # [num_questions, emb_dim]
ce = chunk_embeddings.cpu().numpy()      # [num_chunks, emb_dim]

num_questions = len(qe)
num_calls = 64  # total number of possible calls

k_values = list(range(1, 301))
precisions = []
recalls = []
false_positive_perc = []  # % of wrongly selected calls

for k in tqdm(k_values, desc="Iterating k"):
    tp = 0        # total true positives
    total_true = 0
    total_pred = 0

    for idx, q_emb in enumerate(qe):
        sims = ce @ q_emb
        topk_idx = np.argpartition(-sims, k-1)[:k]
        nearest_calls = {chunks[i][0] + '_combined_text.txt' for i in topk_idx}

        llm_calls = {name + '_combined_text.txt' for name in llm_responses[idx]}
        true_calls = set(true_calls_list[idx])

        pred_calls = nearest_calls | llm_calls
        correct = true_calls & pred_calls

        tp += len(correct)
        total_true += len(true_calls)
        total_pred += len(pred_calls)

    fp_total = total_pred - tp  # all false predictions
    precisions.append(tp / total_pred if total_pred > 0 else np.nan)
    recalls.append(tp / total_true if total_true > 0 else np.nan)
    # average wrong calls per question = fp_total/num_questions
    # as percentage of all possible calls:
    false_positive_perc.append((fp_total / num_questions) / num_calls * 100)

# plot Precision & Recall
plt.figure()
plt.plot(k_values, recalls, label="Recall")
plt.plot(k_values, precisions, label="Precision")
plt.xlabel("k (number of nearest RAG calls)")
plt.ylabel("Micro metric")
plt.title("Precision & Recall for RAG+LLM vs. k")
plt.legend()
plt.grid(True)
plt.show()

# plot % of wrong calls
plt.figure()
plt.plot(k_values, false_positive_perc)
plt.xlabel("k (number of nearest RAG calls)")
plt.ylabel("Average % of incorrectly selected calls")
plt.title("Average percentage of bad calls vs. k")
plt.grid(True)
plt.show()
# Out:
# Iterating k: 100%|██████████| 300/300 [02:30<00:00,  2.00it/s]
